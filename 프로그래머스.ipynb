# %%
import os

from collections import Counter

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fm.fontManager.addfont(font_path)
font_name = fm.FontProperties(fname=font_path).get_name()
plt.rcParams['font.family'] = font_name
plt.rcParams['axes.unicode_minus'] = False

import seaborn as sns

# %%
os.listdir('/home/sjt/space/github/baekjoonhub/프로그래머스')
# Out:
# ['4', '1', 'lv2', 'lv3', '2', 'lv1', 'Lv.2', '3', 'unrated']

# %%
list_py = []
list_sql = []

for (path, dir, files) in os.walk("/home/sjt/space/github/baekjoonhub/프로그래머스"):
    for filename in files:
        if filename[-2:] == 'py':
            list_py.append([path, dir, files])
        if filename[-3:] == 'sql':
            list_sql.append([path, dir, files])

len(list_py), len(list_sql)
# Out:
# (337, 86)

# %%
list_py
# Out:
# [['/home/sjt/space/github/baekjoonhub/프로그래머스/1/12933.\u2005정수\u2005내림차순으로\u2005배치하기',
#   [],
#   ['정수\u2005내림차순으로\u2005배치하기.py', 'README.md']],
#  ['/home/sjt/space/github/baekjoonhub/프로그래머스/1/172928.\u2005공원\u2005산책',
#   [],
#   ['공원\u2005산책.py', 'README.md']],
#  ['/home/sjt/space/github/baekjoonhub/프로그래머스/1/133502.\u2005햄버거\u2005만들기',
#   [],
#   ['햄버거\u2005만들기.py', 'README.md']],
#  ['/home/sjt/space/github/baekjoonhub/프로그래머스/1/142086.\u2005가장\u2005가까운\u2005같은\u2005글자',
#   [],
#   ['가장\u2005가까운\u2005같은\u2005글자.py', 'README.md']],
#  ['/home/sjt/space/github/baekjoonhub/프로그래머스/1/42889.\u2005실패율',
#   [],
#   ['실패율.py', 'README.md']],
#  ['/home/sjt/space/github/baekjoonhub/프로그래머스/1/12912.\u2005두\u2005정수\u2005사이의\u2005합',
#   [],
#   ['두\u2005정수\u2005사이의\u2005합.py', 'README.md']],
#  ['/home/sjt/space/github/baekjoonhub/프로그래머스/1/12977.\u2005소수\u2005만들기',
#   [],
#   ['소수\u2005만들기.py', 'README.md']],
# ...

# %%
list_py_level_1 = []
list_py_level_2 = []
list_py_level_3 = []
list_py_level_4 = []
list_py_level_5 = []


for i in list_py:
    if i[0][41:44] == '/1/':
        list_py_level_1.append(i)
    if i[0][41:44] == '/2/':
        list_py_level_2.append(i)
    if i[0][41:44] == '/3/':
        list_py_level_3.append(i)
    if i[0][41:44] == '/4/':
        list_py_level_4.append(i)
    if i[0][41:44] == '/5/':
        list_py_level_5.append(i)

[len(i) for i in [list_py_level_1,list_py_level_2,list_py_level_3,list_py_level_4,list_py_level_5]]
# Out:
# [71, 37, 3, 0, 0]

# %%
list_sql_level_1 = []
list_sql_level_2 = []
list_sql_level_3 = []
list_sql_level_4 = []
list_sql_level_5 = []


for i in list_sql:
    if i[0][41:44] == '/1/':
        list_sql_level_1.append(i)
    if i[0][41:44] == '/2/':
        list_sql_level_2.append(i)
    if i[0][41:44] == '/3/':
        list_sql_level_3.append(i)
    if i[0][41:44] == '/4/':
        list_sql_level_4.append(i)
    if i[0][41:44] == '/5/':
        list_sql_level_5.append(i)

[len(i) for i in [list_sql_level_1,list_sql_level_2,list_sql_level_3,list_sql_level_4,list_sql_level_5]]
# Out:
# [29, 33, 14, 5, 0]
